# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from ktrain.vision.caption import ImageCaptioner
from ktrain import vision

# %%
ic = ImageCaptioner()

# %%
# !wget https://free-images.com/md/1855/new_york_skyline_usa.jpg -O /tmp/new_york.jpg -q
# !wget https://free-images.com/md/556a/netherlands_landscape_sky_clouds.jpg -O /tmp/netherlands.jpg -q
# !wget https://free-images.com/md/86a4/aroma_aromatic_beverage_bio.jpg -O /tmp/coffee.jpg -q
# !wget https://free-images.com/md/176d/squirrel_tail_bushy_tail.jpg -O /tmp/squirrel.jpg -q

# %%
vision.show_image('/tmp/new_york.jpg')
ic.caption('/tmp/new_york.jpg')
# Out:
# 'a large body of water with a city skyline'

# %%
vision.show_image('/tmp/netherlands.jpg')
ic.caption('/tmp/netherlands.jpg')
# Out:
# 'a grassy field with a boat on the water'

# %%
vision.show_image('/tmp/coffee.jpg')
ic.caption('/tmp/coffee.jpg')
# Out:
# 'a cup of coffee sitting on top of a table'

# %%
vision.show_image('/tmp/squirrel.jpg')
ic.caption('/tmp/squirrel.jpg')
# Out:
# 'a cat standing on top of a wooden fence'

# %% [markdown]
# Well, I guess it kind of looks like cat???  `¯\_(ツ)_/¯`
